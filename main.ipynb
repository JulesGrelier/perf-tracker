# %%
from visualizer import Visualizer, datetime
from parser import Parser_CSV, Measure, Ex

path = "./data.csv"
today = datetime.today()

# %%
parser = Parser_CSV(path)

measure = Measure.as_df(kg=75, nb_reps=(4,3,2), min_repos=(3,4,3), ex=Ex.TRACTION_SUPINATION, date=datetime(2026,4,30))

parser.add_measure(measure).return_df_clone()
# Out:
#                   date  tonnage  nb_reps  nb_series             exercice  \
# 0           2026-04-24     2960       40          2                pompe
# 1           2026-04-27      228        3          1  traction supination
# 2           2026-04-30      675        9          3  traction supination
# 0  2026-04-30 00:00:00      675        9          3  traction supination
#
#    min_repos
# 0        NaN
# 1        NaN
# 2       10.0
# 0       10.0
